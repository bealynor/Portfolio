# %% [markdown]
# ## Portfolio 2: Analysis of Yelp Dataset (Data Processing Techniques)

# %% [markdown]
# The portfolio aims to use various data processing techniques to clean and preprocess the data, filter out irrelevant data, and remove any outliers that could impact the accuracy of the model. Finally, the portfolio aims to use linear regression models to train and validate the model's accuracy in predicting user ratings towards business. Ultimately, the objective is to build a reliable model that can be used to provide insights into user preferences and help businesses make data-driven decisions to improve their services and offerings. In this task, we will explore the impacts of feature selections and different sizes of training/testing data on the model performance. We will use Yelp sub-dataset.

# %% [markdown]
# ### Import the output sample data from Portfolio1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score

import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
#print length of "sample_data"
sample_data = pd.read_csv('Yelp_Portfolio2_Input.csv')
print("The length of the unique businesses is: ", len(sample_data))
# Out:
# The length of the unique businesses is:  38654

# %%
sample_data.head()
# Out:
#             business_categories business_city             business_id  \
# 0   Middle Eastern; Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA
# 1         Tattoo; Beauty & Spas         Tempe  WGNIYMeXPyoWav1APUq7jA
# 2             Tires; Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q
# 3       Sushi Bars; Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA
# 4  Arts & Entertainment; Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw
#
#          date  stars                                               text  \
# 0   14/6/2012      4  love the gyro plate. Rice is so good and I als...
# 1  23/12/2011      4  Good tattoo shop. Clean space, multiple artist...
# 2    9/9/2012      5  Never having dealt with a Discount Tire in Pho...
# 3    4/8/2010      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...
# 4  13/12/2011      4  We got passes for the preview of Mission Impos...
#
#    useful                 user_id
# 0       1  0hT2KtfLiobPvh6cDC8JQg
# 1       2  Xm8HXE1JHqscXe5BKf0GFQ
# 2       0  HLbhD2OyiMCUDRR4c1iXaw
# 3       0  jdoGEEy5s-5L1O_lNzEi2g
# 4       0  Mb0psF4WQF7gZSuZafVr-g

# %% [markdown]
# # Task 1: `business_categories` processing

# %% [markdown]
# You may notice that there are a total of 693 unique business categories present in the sample data. Please write a code snippet to confirm this number. Then, generate a boxplot of `stars` for `business_categories`.

# %%
#code snippet to confirm 693 unique business categories 
unique_category = sample_data['business_categories'].nunique()
unique_category
# Out:
# 693

# %%
#get the data for unique business categories

Category_stars = sample_data.groupby(['business_categories'])['stars'].count().reset_index(name = 'Stars')
Category_stars
# Out:
#                                    business_categories  Stars
# 0    Accessories; Fashion; Shopping; Cosmetics & Be...      4
# 1                                          Active Life     36
# 2                    Active Life; Amateur Sports Teams      6
# 3             Active Life; Amateur Sports Teams; Parks      9
# 4       Active Life; American (New); Golf; Restaurants     17
# 5    Active Life; American (Traditional); Amusement...      3
# 6    Active Life; American (Traditional); Golf; Res...      6
# 7                         Active Life; Amusement Parks     52
# 8    Active Life; Amusement Parks; Climbing; Gyms; ...     23
# 9     Active Life; Amusement Parks; Nightlife; Bowling     22
# 10                                Active Life; Archery      4
# 11              Active Life; Boating; Rafting/Kayaking      5
# 12             Active Life; Burgers; Golf; Restaurants     10
# 13   Active Life; Dog Parks; Amateur Sports Teams; ...     15
# 14                       Active Life; Dog Parks; Parks     31
# 15                 Active Life; Dog Parks; Parks; Pets     10
# 16   Active Life; Event Planning & Services; Party ...     15
# 17                  Active Life; Fitness & Instruction     22
# 18                                   Active Life; Golf     49
# 19                      Active Life; Golf; Restaurants      5
# 20            Active Life; Gyms; Fitness & Instruction     55
# 21   Active Life; Gyms; Trainers; Fitness & Instruc...    111
# 22   Active Life; Health & Medical; Yoga; Physical ...     35
# 23                                 Active Life; Hiking     12
# 24                          Active Life; Hiking; Parks      3
# 25                       Active Life; Horseback Riding     15
# 26                                  Active Life; Lakes     31
# 27                        Active Life; Leisure Centers      5
# 28    Active Life; Martial Arts; Fitness & Instruction     12
# 29   Active Life; Martial Arts; Gyms; Trainers; Fit...      4
# 30   Active Life; Mini Golf; Arts & Entertainment; ...     17
# 31                                  Active Life; Parks    102
# 32   Active Life; Performing Arts; Arts & Entertain...      5
# 33         Active Life; Pilates; Fitness & Instruction      2
# 34                       Active Life; Rafting/Kayaking      4
# 35   Active Life; Recreation Centers; Gyms; Swimmin...     19
# 36                     Active Life; Skate Parks; Parks      3
# 37         Active Life; Skating Rinks; Amusement Parks     20
# 38   Active Life; Sporting Goods; Bikes; Shopping; ...     44
# 39   Active Life; Sporting Goods; Fashion; Shopping...      3
# 40                         Active Life; Swimming Pools      5
# 41                                 Active Life; Tennis     10
# 42        Active Life; Trainers; Fitness & Instruction      3
# 43            Active Life; Yoga; Fitness & Instruction     38
# 44                  Active Life; Zoos; Kids Activities     10
# 45   Acupuncture; Doctors; Health & Medical; Naturo...      7
# 46         Adult Entertainment; Nightlife; Dance Clubs      4
# 47       American (New); Buffets; Tex-Mex; Restaurants      9
# 48                 American (New); Diners; Restaurants     46
# 49          American (New); Mediterranean; Restaurants      6
# 50                         American (New); Restaurants    511
# 51   American (Traditional); American (New); Chicke...     72
# 52        American (Traditional); Buffets; Restaurants     24
# 53   American (Traditional); Comfort Food; Barbeque...      6
# 54   American (Traditional); Comfort Food; Caterers...      6
# 55         American (Traditional); Diners; Restaurants    127
# 56      American (Traditional); Fast Food; Restaurants     34
# 57        American (Traditional); Mexican; Restaurants     37
# 58                 American (Traditional); Restaurants    846
# 59        American (Traditional); Restaurants; Italian      5
# 60     American (Traditional); Sandwiches; Restaurants     20
# 61   American (Traditional); Steakhouses; Seafood; ...     12
# 62        American (Traditional); Tex-Mex; Restaurants     43
# 63                              Argentine; Restaurants      6
# 64   Art Schools; Arts & Entertainment; Specialty S...      4
# 65               Art Supplies; Shopping; Arts & Crafts     21
# 66      Art Supplies; Shopping; Framing; Arts & Crafts     19
# 67   Arts & Crafts; Art Supplies; Shopping; Hobby S...      3
# 68   Arts & Crafts; Fashion; Shopping; Accessories;...      4
# 69                             Arts & Crafts; Shopping     48
# 70                   Arts & Crafts; Shopping; Antiques      9
# 71      Arts & Crafts; Shopping; Baby Gear & Furniture      3
# 72   Arts & Crafts; Shopping; Costumes; Party & Eve...     12
# 73              Arts & Crafts; Shopping; Fabric Stores      8
# 74   Arts & Crafts; Shopping; Jewelry; Home & Garde...      8
# 75                                Arts & Entertainment     15
# 76   Arts & Entertainment; American (New); Nightlif...      6
# 77   Arts & Entertainment; American (Traditional); ...    115
# 78   Arts & Entertainment; Bars; Nightlife; Music V...     60
# 79   Arts & Entertainment; Cafes; Nightlife; Music ...      4
# 80                        Arts & Entertainment; Cinema    218
# 81       Arts & Entertainment; Cinema; Performing Arts     89
# 82                     Arts & Entertainment; Festivals     12
# 83   Arts & Entertainment; Music Venues; Bars; Dive...     82
# 84   Arts & Entertainment; Music Venues; Bars; Nigh...      5
# 85       Arts & Entertainment; Nightlife; Music Venues    160
# 86               Arts & Entertainment; Performing Arts     23
# 87   Arts & Entertainment; Performing Arts; Event P...     60
# 88   Arts & Entertainment; Performing Arts; Music V...     23
# 89   Arts & Entertainment; Pizza; Arcades; Restaurants      7
# 90   Arts & Entertainment; Pool Halls; Shopping; Sp...      3
# 91     Arts & Entertainment; Professional Sports Teams     18
# 92        Arts & Entertainment; Psychics & Astrologers      3
# 93   Arts & Entertainment; Shopping; Art Galleries;...      4
# 94   Arts & Entertainment; Shopping; Home Decor; Ar...      7
# 95   Arts & Entertainment; Specialty Schools; Perfo...      6
# 96             Arts & Entertainment; Stadiums & Arenas    275
# 97         Asian Fusion; Buffets; Chinese; Restaurants     83
# 98                   Asian Fusion; Diners; Restaurants     27
# 99                Asian Fusion; Mongolian; Restaurants    263
# 100                          Asian Fusion; Restaurants     30
# 101                            Auto Repair; Automotive    173
# 102     Auto Repair; Automotive; Auto Parts & Supplies      3
# 103  Auto Repair; Automotive; Auto Parts & Supplies...     13
# 104                Auto Repair; Automotive; Body Shops     14
# 105               Auto Repair; Automotive; Car Dealers     52
# 106    Auto Repair; Automotive; Gas & Service Stations      4
# 107       Auto Repair; Automotive; Oil Change Stations     16
# 108                     Auto Repair; Automotive; Tires     16
# 109  Auto Repair; Automotive; Tires; Auto Parts & S...     20
# 110        Auto Repair; Automotive; Tires; Car Dealers      3
# 111  Auto Repair; Automotive; Windshield Installati...      5
# 112                                         Automotive     10
# 113                    Automotive; Auto Glass Services     11
# 114                  Automotive; Auto Parts & Supplies     19
# 115  Automotive; Auto Parts & Supplies; Auto Glass ...      5
# 116                             Automotive; Body Shops     26
# 117                            Automotive; Car Dealers      3
# 118  Automotive; Electronics; Shopping; Auto Parts ...      5
# 119                 Automotive; Gas & Service Stations     38
# 120                     Automotive; Motorcycle Dealers      4
# 121                             Automotive; RV Dealers      3
# 122  Automotive; Sporting Goods; Bikes; Shopping; M...      5
# 123                                 Automotive; Towing      4
# 124  Automotive; Windows Installation; Home Service...      3
# 125                                     Bakeries; Food     95
# 126  Bakeries; Food; American (Traditional); Restau...     31
# 127                 Bakeries; Food; Cafes; Restaurants      7
# 128  Bakeries; Food; Caterers; Event Planning & Ser...     31
# 129                       Bakeries; Food; Coffee & Tea      8
# 130             Bakeries; Food; Coffee & Tea; Desserts     48
# 131  Bakeries; Food; Coffee & Tea; Sandwiches; Rest...     24
# 132                 Bakeries; Food; Delis; Restaurants     13
# 133                           Bakeries; Food; Desserts     32
# 134              Bakeries; Food; Filipino; Restaurants     13
# 135            Bakeries; Food; Sandwiches; Restaurants    391
# 136          Banks & Credit Unions; Financial Services     37
# 137  Banks & Credit Unions; Financial Services; Mor...      6
# 138                              Barbeque; Restaurants    154
# 139                             Barbers; Beauty & Spas     53
# 140  Bars; American (New); Nightlife; Lounges; Rest...      5
# 141       Bars; American (New); Nightlife; Restaurants      9
# 142  Bars; American (New); Restaurants; Sports Bars...     23
# 143  Bars; American (Traditional); Caribbean; Night...    110
# 144  Bars; American (Traditional); Dance Clubs; Nig...     40
# 145  Bars; American (Traditional); Nightlife; Loung...      5
# 146  Bars; American (Traditional); Nightlife; Resta...    126
# 147  Bars; American (Traditional); Pool Halls; Nigh...     18
# 148  Bars; American (Traditional); Sports Bars; Nig...     98
# 149  Bars; Arts & Entertainment; Nightlife; Music V...      6
# 150  Bars; Burgers; Nightlife; Restaurants; Sports ...     23
# 151  Bars; Chicken Wings; Nightlife; Karaoke; Sport...     13
# 152  Bars; Dive Bars; Burgers; Nightlife; Sports Ba...     76
# 153  Bars; Food; Breweries; Nightlife; American (Ne...    130
# 154  Bars; Food; Breweries; Pubs; Nightlife; Americ...    770
# 155                          Bars; Gay Bars; Nightlife      4
# 156                       Bars; Hookah Bars; Nightlife     12
# 157  Bars; Karaoke; Sports Bars; Dance Clubs; Night...      4
# 158              Bars; Mexican; Nightlife; Restaurants    178
# 159  Bars; Middle Eastern; Nightlife; Lounges; Rest...      4
# 160  Bars; Music Venues; Arts & Entertainment; Nigh...     27
# 161                                    Bars; Nightlife     12
# 162                       Bars; Nightlife; Dance Clubs     25
# 163                           Bars; Nightlife; Karaoke     46
# 164                           Bars; Nightlife; Lounges     45
# 165                        Bars; Pool Halls; Nightlife     56
# 166           Bars; Pool Halls; Nightlife; Sports Bars     50
# 167  Bars; Restaurants; American (Traditional); Spo...     23
# 168          Bars; Restaurants; Sports Bars; Nightlife      3
# 169  Bars; Seafood; Irish; Pubs; Nightlife; Restaur...    311
# 170                       Bars; Sports Bars; Nightlife     48
# 171          Bars; Steakhouses; Nightlife; Restaurants     77
# 172  Beauty & Spas; Hair Removal; Health & Medical;...      3
# 173    Beauty & Spas; Hair Removal; Laser Hair Removal      3
# 174           Beauty & Spas; Hair Removal; Nail Salons      4
# 175                         Beauty & Spas; Nail Salons    201
# 176  Books, Mags, Music & Video; Shopping; Antiques...      4
# 177   Books, Mags, Music & Video; Shopping; Bookstores    193
# 178  Breakfast & Brunch; American (New); Fast Food;...     26
# 179    Breakfast & Brunch; American (New); Restaurants    128
# 180  Breakfast & Brunch; American (Traditional); Di...      3
# 181  Breakfast & Brunch; American (Traditional); Re...    138
# 182  Breakfast & Brunch; Caterers; Sandwiches; Even...     79
# 183            Breakfast & Brunch; Diners; Restaurants     77
# 184                    Breakfast & Brunch; Restaurants    119
# 185        Breakfast & Brunch; Sandwiches; Restaurants     32
# 186                          Bridal; Fashion; Shopping      4
# 187                                   Bridal; Shopping      3
# 188                      Buffets; Chinese; Restaurants     43
# 189                               Buffets; Restaurants     51
# 190                   Building Supplies; Home Services     12
# 191  Burgers; American (Traditional); Fast Food; Re...     33
# 192                     Burgers; Barbeque; Restaurants     15
# 193              Burgers; Bars; Nightlife; Restaurants      4
# 194  Burgers; Breakfast & Brunch; American (Traditi...    182
# 195  Burgers; Breakfast & Brunch; Sandwiches; Resta...     87
# 196          Burgers; Fast Food; Hot Dogs; Restaurants     13
# 197                    Burgers; Fast Food; Restaurants    254
# 198     Burgers; Hot Dogs; American (New); Restaurants    218
# 199                     Burgers; Hot Dogs; Restaurants      6
# 200                               Burgers; Restaurants    827
# 201                      Burgers; Seafood; Restaurants     20
# 202        Burgers; Steakhouses; Barbeque; Restaurants    135
# 203                                 Cafes; Restaurants     19
# 204                     Cafes; Sandwiches; Restaurants     49
# 205     Cajun/Creole; Fast Food; Southern; Restaurants      9
# 206                          Cajun/Creole; Restaurants     27
# 207                Car Stereo Installation; Automotive     14
# 208  Car Stereo Installation; Automotive; Computers...      6
# 209                               Car Wash; Automotive     24
# 210  Car Wash; Automotive; Auto Detailing; Auto Gla...     18
# 211  Car Wash; Automotive; Convenience Stores; Food...      6
# 212       Car Wash; Automotive; Gas & Service Stations      8
# 213  Cards & Stationery; Arts & Crafts; Flowers & G...      8
# 214                             Caribbean; Restaurants     61
# 215                   Cheesesteaks; Pizza; Restaurants     74
# 216              Cheesesteaks; Sandwiches; Restaurants    104
# 217                         Chicken Wings; Restaurants      9
# 218             Children's Clothing; Fashion; Shopping      7
# 219                               Chinese; Restaurants    639
# 220                  Churches; Religious Organizations      4
# 221  Coffee & Tea; Food; Cafes; Chocolatiers & Shop...     10
# 222  Coffee & Tea; Food; Caterers; Sandwiches; Rest...      9
# 223  Coffee & Tea; Hawaiian; Food; Venues & Event S...     16
# 224  Colleges & Universities; Doctors; Education; H...      3
# 225                 Colleges & Universities; Education     58
# 226  Comic Books; Shopping; Books, Mags, Music & Video     11
# 227                                Computers; Shopping      3
# 228     Computers; Shopping; Home & Garden; Appliances     12
# 229             Creperies; Fondue; French; Restaurants    114
# 230                                 Cuban; Restaurants      2
# 231                     DJs; Event Planning & Services      3
# 232                            Day Spas; Beauty & Spas     35
# 233               Day Spas; Beauty & Spas; Nail Salons      5
# 234          Delis; Fast Food; Sandwiches; Restaurants     18
# 235                        Delis; Italian; Restaurants      5
# 236                          Delis; Pizza; Restaurants      3
# 237                                 Delis; Restaurants    131
# 238  Delis; Restaurants; Event Planning & Services;...      8
# 239                     Delis; Sandwiches; Restaurants    131
# 240               Department Stores; Fashion; Shopping    136
# 241   Department Stores; Fashion; Shopping; Drugstores      5
# 242  Department Stores; Fashion; Shopping; Home & G...      5
# 243  Department Stores; Fashion; Shopping; Shopping...      3
# 244  Department Stores; Grocery; Fashion; Shopping;...     29
# 245  Departments of Motor Vehicles; Public Services...     27
# 246  Desserts; Food; Caterers; Specialty Food; Even...     10
# 247                                Diners; Restaurants     66
# 248                           Discount Store; Shopping      6
# 249   Dive Bars; Bars; Mexican; Nightlife; Restaurants     69
# 250                         Dive Bars; Bars; Nightlife      3
# 251   Dive Bars; Bars; Nightlife; Lounges; Restaurants     29
# 252            Dive Bars; Bars; Nightlife; Restaurants     35
# 253       Doctors; Ear Nose & Throat; Health & Medical      4
# 254                          Doctors; Health & Medical     14
# 255  Doctors; Health & Medical; Family Practice; Ur...     16
# 256       Doctors; Health & Medical; Internal Medicine     10
# 257   Doctors; Health & Medical; Naturopathic/Holistic      6
# 258  Doctors; Health & Medical; Obstetricians & Gyn...      6
# 259           Doctors; Health & Medical; Pediatricians      9
# 260  Doctors; Health & Medical; Pediatricians; Inte...      5
# 261             Doctors; Health & Medical; Urgent Care      9
# 262                                          Education      2
# 263  Electricians; Lighting Fixtures & Equipment; H...     28
# 264  Electronics; Musical Instruments & Teachers; S...      8
# 265               Electronics; Shopping; Mobile Phones      3
# 266          Elementary Schools; Education; Preschools      3
# 267  Elementary Schools; Middle Schools & High Scho...      3
# 268  Endodontists; Health & Medical; Dentists; Gene...      4
# 269                             Ethiopian; Restaurants      3
# 270                      Ethiopian; Vegan; Restaurants    102
# 271                Event Planning & Services; Caterers      3
# 272  Event Planning & Services; Party & Event Planning      8
# 273   Event Planning & Services; Venues & Event Spaces      6
# 274                                  Fashion; Shopping     28
# 275                     Fashion; Shopping; Shoe Stores     21
# 276  Fashion; Shopping; Sporting Goods; Accessories...      4
# 277  Fashion; Shopping; Sporting Goods; Bikes; Outd...     48
# 278                    Fast Food; Mexican; Restaurants     52
# 279                             Fast Food; Restaurants    159
# 280                 Fast Food; Sandwiches; Restaurants     18
# 281                    Fast Food; Tex-Mex; Restaurants     14
# 282                      Financial Services; Insurance     11
# 283                          Fish & Chips; Restaurants     42
# 284                          Flowers & Gifts; Shopping      7
# 285                Flowers & Gifts; Shopping; Florists     17
# 286                                Fondue; Restaurants     42
# 287                                               Food     15
# 288       Food; American (New); Breweries; Restaurants     50
# 289               Food; Arts & Entertainment; Wineries     13
# 290       Food; Asian Fusion; Food Trucks; Restaurants      4
# 291  Food; Automotive; Convenience Stores; Gas & Se...      6
# 292  Food; Automotive; Convenience Stores; Gas & Se...      4
# 293                         Food; Automotive; Shopping      6
# 294                                       Food; Bagels     23
# 295      Food; Bagels; Breakfast & Brunch; Restaurants     52
# 296                   Food; Bagels; Delis; Restaurants     46
# 297         Food; Bakeries; Delis; Bagels; Restaurants    213
# 298                         Food; Beer, Wine & Spirits    238
# 299  Food; Beer, Wine & Spirits; American (Traditio...     49
# 300        Food; Beer, Wine & Spirits; Bars; Nightlife     33
# 301  Food; Beer, Wine & Spirits; Bars; Sports Bars;...     20
# 302     Food; Beer, Wine & Spirits; Convenience Stores      5
# 303                Food; Beer, Wine & Spirits; Grocery    122
# 304  Food; Beer, Wine & Spirits; Irish; American (T...     33
# 305  Food; Beer, Wine & Spirits; Shopping; Home & G...      6
# 306                                    Food; Breweries     79
# 307  Food; Burgers; Ice Cream & Frozen Yogurt; Dine...     76
# 308       Food; Cajun/Creole; Food Trucks; Restaurants      4
# 309                 Food; Cheese Shops; Specialty Food      5
# 310                         Food; Chinese; Restaurants     14
# 311                                 Food; Coffee & Tea   1065
# 312    Food; Coffee & Tea; American (New); Restaurants     78
# 313  Food; Coffee & Tea; Art Galleries; Shopping; A...     14
# 314           Food; Coffee & Tea; Arts & Entertainment     34
# 315             Food; Coffee & Tea; Cafes; Restaurants      7
# 316  Food; Coffee & Tea; Creperies; Cafes; Restaurants     47
# 317         Food; Coffee & Tea; Creperies; Restaurants     74
# 318  Food; Coffee & Tea; Event Planning & Services;...     59
# 319                 Food; Coffee & Tea; Internet Cafes      6
# 320        Food; Coffee & Tea; Sandwiches; Restaurants     64
# 321                           Food; Convenience Stores     25
# 322    Food; Convenience Stores; Hot Dogs; Restaurants     15
# 323                           Food; Delis; Restaurants      3
# 324  Food; Department Stores; Grocery; Fashion; Sho...      4
# 325                                     Food; Desserts     42
# 326                           Food; Desserts; Bakeries     64
# 327                       Food; Desserts; Coffee & Tea      3
# 328  Food; Desserts; Coffee & Tea; Sandwiches; Rest...     77
# 329       Food; Desserts; Delis; Bakeries; Restaurants     14
# 330          Food; Desserts; Ice Cream & Frozen Yogurt     76
# 331               Food; Desserts; Restaurants; Italian     13
# 332  Food; Desserts; Specialty Food; Chocolatiers &...      3
# 333      Food; Do-It-Yourself Food; Pizza; Restaurants      3
# 334                                       Food; Donuts    116
# 335      Food; Donuts; Breakfast & Brunch; Restaurants      4
# 336                         Food; Donuts; Coffee & Tea     40
# 337                 Food; Donuts; Coffee & Tea; Bagels      6
# 338  Food; Ethnic Food; Specialty Food; Japanese; R...     39
# 339  Food; Ethnic Food; Thai; Specialty Food; Resta...     11
# 340                               Food; Farmers Market     10
# 341                       Food; Food Delivery Services      6
# 342  Food; Food Delivery Services; Delis; Sandwiche...    219
# 343                           Food; Greek; Restaurants      9
# 344                                      Food; Grocery    268
# 345                  Food; Grocery; Convenience Stores      7
# 346                      Food; Grocery; Farmers Market     37
# 347                Food; Grocery; Shopping; Drugstores     37
# 348                        Food; Hawaiian; Restaurants     24
# 349      Food; Health Markets; Grocery; Specialty Food    118
# 350               Food; Herbs & Spices; Specialty Food     48
# 351                    Food; Ice Cream & Frozen Yogurt    648
# 352  Food; Ice Cream & Frozen Yogurt; American (Tra...      5
# 353          Food; Ice Cream & Frozen Yogurt; Desserts     61
# 354  Food; Ice Cream & Frozen Yogurt; Fast Food; Re...      6
# 355  Food; Ice Cream & Frozen Yogurt; Juice Bars & ...     15
# 356    Food; Ice Cream & Frozen Yogurt; Street Vendors      6
# 357  Food; Ice Cream & Frozen Yogurt; Vegan; Restau...     56
# 358                       Food; Juice Bars & Smoothies     24
# 359   Food; Juice Bars & Smoothies; Cafes; Restaurants      8
# 360  Food; Juice Bars & Smoothies; Sandwiches; Rest...     16
# 361                 Food; Korean; Grocery; Restaurants     27
# 362             Food; Pubs; Bars; Breweries; Nightlife      8
# 363                   Food; Shopping Centers; Shopping    117
# 364                         Food; Shopping; Drugstores      6
# 365                               Food; Specialty Food     17
# 366                 Food; Specialty Food; Candy Stores     17
# 367  Food; Specialty Food; Candy Stores; Chocolatie...     26
# 368  Food; Specialty Food; Candy Stores; Ice Cream ...      4
# 369         Food; Specialty Food; Chocolatiers & Shops      6
# 370  Food; Specialty Food; Fruits & Veggies; Food D...      3
# 371                   Food; Specialty Food; Meat Shops      3
# 372        Food; Street Vendors; Hot Dogs; Restaurants      4
# 373         Food; Street Vendors; Mexican; Restaurants      6
# 374  Food; Tea Rooms; American (Traditional); Resta...      7
# 375  Food; Vegetarian; Juice Bars & Smoothies; Vega...     79
# 376  Food; Weight Loss Centers; Juice Bars & Smooth...      6
# 377              Gardeners; Landscaping; Home Services      3
# 378                            Gastropubs; Restaurants     29
# 379  Gastropubs; Wine Bars; Bars; Nightlife; Restau...     51
# 380                                German; Restaurants    166
# 381    Gluten-Free; Asian Fusion; Chinese; Restaurants     96
# 382                  Greek; Mediterranean; Restaurants    131
# 383                 Greek; Middle Eastern; Restaurants     80
# 384                                 Greek; Restaurants     99
# 385         Greek; Restaurants; Mediterranean; Italian      7
# 386  Grocery; Food; Ethnic Food; Indian; Specialty ...     46
# 387  Grocery; Food; Ethnic Food; Japanese; Specialt...     42
# 388  Grocery; Shopping; Florists; Drugstores; Food;...      8
# 389  Grocery; Shopping; Florists; Food; Beer, Wine ...     23
# 390                        Hair Removal; Beauty & Spas      9
# 391                Hair Salons; Barbers; Beauty & Spas      9
# 392                         Hair Salons; Beauty & Spas     74
# 393            Hair Salons; Beauty & Spas; Nail Salons      9
# 394               Hair Salons; Day Spas; Beauty & Spas      9
# 395            Hair Salons; Nail Salons; Beauty & Spas     19
# 396  Hair Salons; Shopping; Cosmetics & Beauty Supp...     12
# 397  Hair Salons; Skin Care; Nail Salons; Beauty & ...      8
# 398  Hardware Stores; Building Supplies; Shopping; ...      4
# 399           Hardware Stores; Shopping; Home & Garden     20
# 400                     Hawaiian; Chinese; Restaurants      6
# 401                              Hawaiian; Restaurants     48
# 402                                   Health & Medical      4
# 403                    Health & Medical; Chiropractors     10
# 404                         Health & Medical; Dentists      8
# 405      Health & Medical; Dentists; Cosmetic Dentists      3
# 406      Health & Medical; Dentists; General Dentistry     37
# 407  Health & Medical; Dentists; General Dentistry;...      9
# 408          Health & Medical; Dentists; Orthodontists      3
# 409                        Health & Medical; Hospitals     38
# 410                 Health & Medical; Physical Therapy      3
# 411  Health & Medical; Physical Therapy; Massage; B...      3
# 412                      Health & Medical; Urgent Care     31
# 413  Health Markets; Food; Grocery; Ethnic Food; Sp...     39
# 414               Health Markets; Food; Specialty Food      3
# 415  Health Markets; Food; Specialty Food; Restaurants      4
# 416                              Hobby Shops; Shopping     12
# 417      Home & Garden; Shopping; Home Decor; Antiques     16
# 418  Home & Garden; Shopping; Home Services; Floori...      3
# 419                       Home Cleaning; Home Services     14
# 420  Home Cleaning; Professional Services; Office C...      4
# 421                                      Home Services      3
# 422  Home Services; Apartments; Real Estate Service...      3
# 423  Home Services; Carpet Cleaning; Local Services...      9
# 424                         Home Services; Contractors     24
# 425                            Home Services; Flooring      3
# 426     Home Services; Heating & Air Conditioning/HVAC     12
# 427  Home Services; Heating & Air Conditioning/HVAC...      6
# 428             Home Services; Real Estate; Apartments     49
# 429                 Hot Dogs; Food Stands; Restaurants      3
# 430                              Hot Dogs; Restaurants    327
# 431            Hot Tub & Pool; Shopping; Home & Garden      7
# 432          Hotels & Travel; Airlines; Transportation      3
# 433  Hotels & Travel; Airport Shuttles; Limos; Tran...      3
# 434                   Hotels & Travel; Bed & Breakfast      3
# 435  Hotels & Travel; Bed & Breakfast; Event Planni...      5
# 436                        Hotels & Travel; Car Rental     18
# 437  Hotels & Travel; Event Planning & Services; Ho...    497
# 438  Hotels & Travel; Event Planning & Services; Ve...     26
# 439  Hotels & Travel; Public Transportation; Transp...      3
# 440                             Hotels & Travel; Tours      3
# 441                    Hotels & Travel; Transportation      5
# 442                   Hotels & Travel; Travel Services      5
# 443  Hotels & Travel; Travel Services; Airlines; Tr...     40
# 444  Ice Cream & Frozen Yogurt; Food; Restaurants; ...     11
# 445                       Indian; Buffets; Restaurants    110
# 446                     Indian; Pakistani; Restaurants     39
# 447                                Indian; Restaurants    140
# 448  Italian; American (New); Mediterranean; Restau...     61
# 449               Italian; American (New); Restaurants      4
# 450           Italian; Pizza; Gluten-Free; Restaurants     29
# 451                        Italian; Pizza; Restaurants    536
# 452                              Japanese; Restaurants    187
# 453  Jazz & Blues; Arts & Entertainment; Nightlife;...      8
# 454                   Keys & Locksmiths; Home Services     13
# 455                       Korean; Chinese; Restaurants     33
# 456                      Korean; Hawaiian; Restaurants     49
# 457            Korean; Japanese; Barbeque; Restaurants      4
# 458                      Korean; Japanese; Restaurants     41
# 459                                Korean; Restaurants    110
# 460          Korean; Sushi Bars; Japanese; Restaurants      9
# 461  Laboratory Testing; Diagnostic Services; Healt...      3
# 462                         Landscaping; Home Services     11
# 463   Landscaping; Landscape Architects; Home Services     10
# 464            Libraries; Public Services & Government     27
# 465                        Lingerie; Shopping; Fashion      6
# 466                 Lingerie; Shopping; Fashion; Adult     11
# 467     Live/Raw Food; Gluten-Free; Vegan; Restaurants     18
# 468                                       Local Flavor     36
# 469                                     Local Services     11
# 470  Local Services; Active Life; Gyms; Child Care ...      7
# 471                Local Services; Appliances & Repair     12
# 472  Local Services; Automotive; Community Service/...      6
# 473  Local Services; Automotive; Truck Rental; Self...      7
# 474       Local Services; Community Service/Non-Profit      9
# 475  Local Services; Community Service/Non-Profit; ...      6
# 476  Local Services; Computers; Shopping; IT Servic...      7
# 477  Local Services; Couriers & Delivery Services; ...      4
# 478             Local Services; Dry Cleaning & Laundry     87
# 479  Local Services; Dry Cleaning & Laundry; Sewing...      7
# 480             Local Services; Furniture Reupholstery      6
# 481  Local Services; Home & Garden; Shopping; Appli...      3
# 482      Local Services; IT Services & Computer Repair      7
# 483             Local Services; Junk Removal & Hauling      3
# 484                       Local Services; Pest Control     17
# 485                  Local Services; Printing Services      3
# 486               Local Services; Sewing & Alterations     33
# 487                   Local Services; Shipping Centers     14
# 488         Local Services; Shipping Centers; Notaries      3
# 489  Local Services; Shipping Centers; Printing Ser...     13
# 490                        Local Services; Shoe Repair     18
# 491                         Mass Media; Radio Stations     16
# 492                  Massage Therapy; Health & Medical      7
# 493                             Massage; Beauty & Spas     19
# 494  Mattresses; Shopping; Home Decor; Home & Garde...      5
# 495                  Medical Centers; Health & Medical      7
# 496  Medical Centers; Pilates; Health & Medical; Tr...      3
# 497  Mediterranean; Greek; Middle Eastern; Restaurants     37
# 498         Mediterranean; Middle Eastern; Restaurants      9
# 499                         Mediterranean; Restaurants     25
# 500             Mediterranean; Sandwiches; Restaurants     27
# 501                  Men's Clothing; Fashion; Shopping     24
# 502     Men's Clothing; Fashion; Shopping; Formal Wear      5
# 503                    Mexican; Nightlife; Restaurants     13
# 504                               Mexican; Restaurants   2211
# 505  Middle Eastern; Greek; Mediterranean; Restaurants      6
# 506         Middle Eastern; Mediterranean; Restaurants     45
# 507                        Middle Eastern; Restaurants    457
# 508  Middle Schools & High Schools; Elementary Scho...      4
# 509                              Movers; Home Services     12
# 510                      Museums; Arts & Entertainment     11
# 511  Music & DVDs; Books, Mags, Music & Video; Shop...    115
# 512  Music & DVDs; Books, Mags, Music & Video; Shop...      5
# 513  Music Venues; Arts & Entertainment; Event Plan...     27
# 514           Musical Instruments & Teachers; Shopping      3
# 515                                          Nightlife     27
# 516  Nightlife; Arts & Entertainment; Karaoke; Soci...     11
# 517  Nightlife; Bars; American (Traditional); Sport...     35
# 518   Nightlife; Bars; Pizza; Sports Bars; Restaurants     97
# 519  Nightlife; Bars; Sports Bars; Barbeque; Restau...     10
# 520  Nightlife; Bars; Sushi Bars; Japanese; Restaur...    143
# 521                            Nightlife; Comedy Clubs     67
# 522  Nightlife; Venues & Event Spaces; Event Planni...     13
# 523                    Oil Change Stations; Automotive      6
# 524                     Optometrists; Health & Medical      7
# 525  Optometrists; Ophthalmologists; Health & Medic...      3
# 526    Painters; Electricians; Handyman; Home Services      6
# 527            Pakistani; Indian; Buffets; Restaurants    116
# 528  Party Supplies; Discount Store; Shopping; Even...      3
# 529          Party Supplies; Event Planning & Services      8
# 530  Party Supplies; Event Planning & Services; Ven...      3
# 531                       Persian/Iranian; Restaurants     58
# 532                              Peruvian; Restaurants     45
# 533                   Pet Groomers; Pet Services; Pets     15
# 534                  Pet Services; Home Services; Pets      7
# 535       Pet Services; Pet Boarding/Pet Sitting; Pets     36
# 536  Pet Services; Pet Groomers; Pet Boarding/Pet S...      3
# 537  Pet Services; Pet Groomers; Pet Training; Pets...      5
# 538                     Pet Services; Pet Stores; Pets     15
# 539  Pet Services; Pet Training; Pet Boarding/Pet S...      4
# 540  Pet Services; Veterinarians; Pet Boarding/Pet ...     10
# 541                                   Pets; Pet Stores     54
# 542           Photographers; Event Planning & Services     10
# 543  Photographers; Event Planning & Services; Sess...      3
# 544  Piano Bars; Arts & Entertainment; Nightlife; M...    122
# 545                            Piercing; Beauty & Spas     76
# 546  Pilates; Chiropractors; Health & Medical; Trai...      4
# 547                    Pizza; Gluten-Free; Restaurants     60
# 548                                 Pizza; Restaurants   1050
# 549                            Plumbing; Home Services      7
# 550                                Polish; Restaurants     61
# 551                  Polish; Scandinavian; Restaurants    160
# 552  Pool Halls; American (New); Nightlife; Restaur...      9
# 553                              Pool Halls; Nightlife     15
# 554         Post Offices; Public Services & Government     31
# 555                            Print Media; Mass Media     10
# 556                              Professional Services      3
# 557  Professional Services; Bankruptcy Law; Lawyers...      8
# 558  Professional Services; Event Planning & Servic...      4
# 559              Professional Services; Graphic Design      4
# 560  Professional Services; Graphic Design; Web Design      4
# 561  Professional Services; Television Service Prov...      3
# 562  Property Management; Home Services; Real Estat...      3
# 563                       Public Services & Government      7
# 564        Pubs; Bars; Nightlife; British; Restaurants    567
# 565          Pubs; Bars; Nightlife; Irish; Restaurants    233
# 566                     Pubs; Bars; Nightlife; Lounges     64
# 567     Pubs; Bars; Nightlife; Sandwiches; Restaurants     97
# 568                   Pubs; Wine Bars; Bars; Nightlife     67
# 569   Real Estate Services; Home Services; Real Estate      6
# 570     Real Estate; Home Services; Real Estate Agents      7
# 571                            Religious Organizations      7
# 572                                        Restaurants    189
# 573                             Restaurants; Brazilian      4
# 574                  Restaurants; Gluten-Free; Italian     30
# 575                               Restaurants; Italian    577
# 576  Restaurants; Mexican; Event Planning & Service...      8
# 577                        Restaurants; Pizza; Italian    257
# 578                               Restaurants; Turkish     85
# 579                             Roofing; Home Services      3
# 580                            Sandwiches; Restaurants    689
# 581                          Scandinavian; Restaurants     27
# 582       Seafood; American (Traditional); Restaurants     91
# 583                      Seafood; Buffets; Restaurants     66
# 584                               Seafood; Restaurants    153
# 585                      Seafood; Restaurants; Italian     71
# 586     Seafood; Steakhouses; Gluten-Free; Restaurants     45
# 587        Shades & Blinds; Home Services; Contractors      9
# 588    Shades & Blinds; Interior Design; Home Services      3
# 589                                           Shopping     45
# 590  Shopping Centers; Fashion; Shopping; Departmen...     54
# 591                         Shopping Centers; Shopping    151
# 592                                 Shopping; Antiques     19
# 593  Shopping; Automotive; Computers; Home & Garden...     14
# 594                    Shopping; Baby Gear & Furniture     10
# 595  Shopping; Cosmetics & Beauty Supply; Beauty & ...     39
# 596                               Shopping; Drugstores     45
# 597  Shopping; Drugstores; Beauty & Spas; Food; Con...     12
# 598                      Shopping; Eyewear & Opticians      5
# 599                              Shopping; Guns & Ammo      4
# 600                  Shopping; Guns & Ammo; Pawn Shops     10
# 601                            Shopping; Home & Garden     12
# 602                Shopping; Home & Garden; Appliances      3
# 603          Shopping; Home & Garden; Furniture Stores     19
# 604                Shopping; Home Decor; Home & Garden     15
# 605  Shopping; Home Decor; Home & Garden; Furniture...    172
# 606  Shopping; Home Services; Building Supplies; Ho...     19
# 607  Shopping; Home Services; Flooring; Home & Gard...      5
# 608  Shopping; Home Services; Internet Service Prov...     20
# 609                                  Shopping; Jewelry     18
# 610                            Shopping; Mobile Phones     20
# 611     Shopping; Nurseries & Gardening; Home & Garden     10
# 612                         Shopping; Office Equipment     18
# 613  Shopping; Optometrists; Health & Medical; Eyew...      6
# 614                            Shopping; Outlet Stores      6
# 615            Shopping; Photography Stores & Services     34
# 616  Shopping; Sporting Goods; Gyms; Venues & Event...      5
# 617                               Shopping; Toy Stores     21
# 618                      Shopping; Watches; Pawn Shops      4
# 619                         Shopping; Wholesale Stores     14
# 620                 Skin Care; Day Spas; Beauty & Spas      3
# 621  Skin Care; Day Spas; Beauty & Spas; Health & M...     18
# 622    Skin Care; Day Spas; Hair Salons; Beauty & Spas      5
# 623        Skin Care; Day Spas; Massage; Beauty & Spas     19
# 624          Skin Care; Eyelash Service; Beauty & Spas      3
# 625             Skin Care; Hair Removal; Beauty & Spas      3
# 626              Skin Care; Nail Salons; Beauty & Spas      7
# 627  Solar Installation; Home Services; Heating & A...      6
# 628                        Soup; Japanese; Restaurants    167
# 629                    Southern; Barbeque; Restaurants    190
# 630                              Southern; Restaurants      7
# 631                  Spanish; Steakhouses; Restaurants     22
# 632  Specialty Schools; Massage Schools; Education;...      7
# 633                    Sporting Goods; Bikes; Shopping     36
# 634     Sporting Goods; Fashion; Shopping; Shoe Stores      9
# 635  Sporting Goods; Fashion; Shopping; Shoe Stores...     27
# 636     Sporting Goods; Fashion; Shopping; Sports Wear      8
# 637                           Sporting Goods; Shopping     94
# 638             Sporting Goods; Shopping; Outdoor Gear      8
# 639                           Steakhouses; Restaurants    134
# 640               Steakhouses; Sushi Bars; Restaurants    112
# 641                  Sushi Bars; Japanese; Restaurants    497
# 642                            Sushi Bars; Restaurants    396
# 643                             Tanning; Beauty & Spas     16
# 644                    Tanning; Massage; Beauty & Spas      4
# 645                              Tattoo; Beauty & Spas     36
# 646                    Tattoo; Piercing; Beauty & Spas      3
# 647                               Tex-Mex; Restaurants    223
# 648                                  Thai; Restaurants    797
# 649                      Thai; Vegetarian; Restaurants    159
# 650                      Thai; Vietnamese; Restaurants     79
# 651   Thrift Stores; Men's Clothing; Fashion; Shopping      6
# 652                            Thrift Stores; Shopping     68
# 653                                  Tires; Automotive    107
# 654           Tires; Automotive; Auto Parts & Supplies      3
# 655                     Tires; Automotive; Auto Repair      3
# 656  Tires; Automotive; Fashion; Shopping; Departme...     24
# 657             Tires; Automotive; Oil Change Stations      7
# 658  Tobacco Shops; Pool Halls; Shopping; Nightlife...      2
# 659                            Tobacco Shops; Shopping     20
# 660                                 Uniforms; Shopping      3
# 661     Used, Vintage & Consignment; Fashion; Shopping     33
# 662  Vegetarian; American (New); Mediterranean; Res...    365
# 663    Vegetarian; American (Traditional); Restaurants    192
# 664        Vegetarian; Gluten-Free; Vegan; Restaurants     26
# 665                    Vegetarian; Indian; Restaurants     88
# 666                  Vegetarian; Japanese; Restaurants      3
# 667                     Vegetarian; Vegan; Restaurants    466
# 668                                Veterinarians; Pets     66
# 669  Videos & Video Game Rental; Books, Mags, Music...      7
# 670  Videos & Video Game Rental; Books, Mags, Music...      7
# 671  Videos & Video Game Rental; Books, Mags, Music...     18
# 672  Videos & Video Game Rental; Books, Mags, Music...      3
# 673  Videos & Video Game Rental; Books, Mags, Music...      6
# 674  Videos & Video Game Rental; Books, Mags, Music...      3
# 675              Vietnamese; Asian Fusion; Restaurants     83
# 676                            Vietnamese; Restaurants    491
# 677  Weight Loss Centers; Beauty & Spas; Health & M...      5
# 678                      Window Washing; Home Services     12
# 679                         Wine Bars; Bars; Nightlife     11
# 680     Wine Bars; Bars; Pizza; Nightlife; Restaurants    298
# 681  Women's Clothing; Department Stores; Fashion; ...     18
# 682                Women's Clothing; Fashion; Shopping     34
# 683   Women's Clothing; Fashion; Shopping; Accessories     30
# 684  Women's Clothing; Lingerie; Shopping; Fashion;...     10
# 685  Women's Clothing; Men's Clothing; Fashion; Sho...      4
# 686  Women's Clothing; Men's Clothing; Fashion; Sho...     21
# 687  Women's Clothing; Men's Clothing; Fashion; Sho...     26
# 688  Women's Clothing; Men's Clothing; Fashion; Sho...      6
# 689  Women's Clothing; Men's Clothing; Fashion; Sho...     14
# 690  Women's Clothing; Thrift Stores; Shopping; Fas...      5
# 691  Women's Clothing; Used, Vintage & Consignment;...     11
# 692  Women's Clothing; Used, Vintage & Consignment;...     69

# %%
#generate a boxplot of `stars` for `business_categories'
Category_stars.boxplot('Stars')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Sometimes we need to extract some major categories, such as `Middle Eastern; Restaurants` and `Sushi Bars; Restaurants`, both of which should belong to the `Restaurants` category.

# %% [markdown]
# ### Task 1.1 : Efficiently and accurately extracting the last category value (i.e., categorieN) from the `business_categories` column in a dataset, where the format of each row is a semicolon-separated list of categories (i.e., 'categorie1; categorie2;...;categorieN'), and replacing the original string with this last category value.

# %%
#define the function to split business category and return only last value
def last_value(string):
    return string.split()[-1]

#display only the last value of each input in the business categories column
sample_data['business_categories'] = sample_data['business_categories'].apply(lambda x: last_value(x.split(';')[-1]))
sample_data.reset_index()
sample_data.head()
# Out:
#   business_categories business_city             business_id        date  \
# 0         Restaurants         Tempe  6oRAC4uyJCsJl1X0WZpVSA   14/6/2012
# 1                Spas         Tempe  WGNIYMeXPyoWav1APUq7jA  23/12/2011
# 2          Automotive      Glendale  rxQ2PIjhAx6dgAqUalf99Q    9/9/2012
# 3         Restaurants         Tempe  EC9WB-iVjd28B6R6KIZ8TA    4/8/2010
# 4              Cinema         Tempe  LDJhwZN14AZOJyHjg2lkRw  13/12/2011
#
#    stars                                               text  useful  \
# 0      4  love the gyro plate. Rice is so good and I als...       1
# 1      4  Good tattoo shop. Clean space, multiple artist...       2
# 2      5  Never having dealt with a Discount Tire in Pho...       0
# 3      4  Cliff notes\n- Cheap: $1-2/plate\n- Fast: It's...       0
# 4      4  We got passes for the preview of Mission Impos...       0
#
#                   user_id
# 0  0hT2KtfLiobPvh6cDC8JQg
# 1  Xm8HXE1JHqscXe5BKf0GFQ
# 2  HLbhD2OyiMCUDRR4c1iXaw
# 3  jdoGEEy5s-5L1O_lNzEi2g
# 4  Mb0psF4WQF7gZSuZafVr-g

# %% [markdown]
# ### Task1.2 : Check how many unique business categories are present in the dataset (output from Task 1.1). Display `ALL Rows` of the business category count data, which is to count and print the number of occurrences for each business category.

# %%
#number of unique businesses 
unique_category = sample_data['business_categories'].nunique()
unique_category
# Out:
# 139

# %%
#display all rows of business category count data
businesscat_count = sample_data['business_categories'].value_counts().reset_index()
pd.set_option('display.max_rows', None)
businesscat_count
# Out:
#                      index  business_categories
# 0              Restaurants                25212
# 1                      Tea                 1116
# 2                 Shopping                 1099
# 3                  Italian                  960
# 4                   Yogurt                  728
# 5                   Hotels                  528
# 6                     Spas                  498
# 7                   Stores                  451
# 8                Nightlife                  399
# 9                 Services                  396
# 10                 Grocery                  390
# 11                    Food                  351
# 12                  Venues                  348
# 13             Instruction                  336
# 14              Automotive                  334
# 15                  Arenas                  275
# 16                 Spirits                  242
# 17                   Parks                  235
# 18                  Salons                  219
# 19                  Cinema                  218
# 20              Bookstores                  208
# 21                Desserts                  183
# 22                    Pets                  166
# 23                  Donuts                  116
# 24                   Clubs                  115
# 25                    Arts                  112
# 26                 Lounges                  109
# 27                   Shops                  105
# 28                Stations                  101
# 29                    Wear                   95
# 30                Clothing                   95
# 31              Drugstores                   93
# 32              Government                   92
# 33                 Laundry                   87
# 34                 Turkish                   85
# 35                 Dealers                   83
# 36               Breweries                   79
# 37                Caterers                   78
# 38           Entertainment                   74
# 39               Education                   73
# 40                  Spaces                   69
# 41                  Garden                   68
# 42             Accessories                   66
# 43                Bakeries                   64
# 44                    Care                   56
# 45          Transportation                   54
# 46                  Phones                   52
# 47              Apartments                   52
# 48                 Medical                   52
# 49                  Repair                   50
# 50                Supplies                   50
# 51                    Bars                   50
# 52                    Golf                   49
# 53                 Karaoke                   48
# 54              Appliances                   48
# 55                  Market                   47
# 56             Contractors                   45
# 57                Antiques                   44
# 58                 Rentals                   44
# 59                    Life                   43
# 60             Alterations                   40
# 61                  Crafts                   40
# 62               Smoothies                   39
# 63               Hospitals                   38
# 64               Dentistry                   37
# 65                 Bowling                   37
# 66                  Flavor                   36
# 67              Sandwiches                   31
# 68               Furniture                   31
# 69                   Lakes                   31
# 70                   Gifts                   31
# 71                  Bagels                   29
# 72            Installation                   28
# 73                 Centers                   26
# 74                 Jewelry                   24
# 75                   Teams                   24
# 76                Dentists                   24
# 77                   Pizza                   23
# 78             Electronics                   20
# 79               Equipment                   18
# 80                  Rental                   18
# 81                Florists                   17
# 82                 Control                   17
# 83                 Arcades                   17
# 84                   Decor                   16
# 85                   Tires                   16
# 86   Naturopathic/Holistic                   16
# 87      Service/Non-Profit                   15
# 88                Medicine                   15
# 89                  Riding                   15
# 90           Organizations                   15
# 91                  Estate                   15
# 92                Wineries                   13
# 93                  Hiking                   12
# 94               Festivals                   12
# 95       Conditioning/HVAC                   12
# 96                  Supply                   12
# 97                Planning                   11
# 98                   Adult                   11
# 99                   Video                   11
# 100              Insurance                   11
# 101              Opticians                   11
# 102                 Tennis                   10
# 103             Activities                   10
# 104                  Media                   10
# 105          Chiropractors                   10
# 106       Rafting/Kayaking                    9
# 107          Pediatricians                    9
# 108                 Design                    8
# 109                   Gear                    8
# 110             Litigation                    8
# 111                Storage                    7
# 112                   DVDs                    7
# 113                 Agents                    7
# 114                Removal                    6
# 115          Gynecologists                    6
# 116                Vendors                    6
# 117                  Cafes                    6
# 118                Fashion                    6
# 119           Reupholstery                    6
# 120                  Pools                    5
# 121               Costumes                    4
# 122          Photographers                    4
# 123                   Ammo                    4
# 124                 Towing                    4
# 125              Brazilian                    4
# 126                Archery                    4
# 127               Flooring                    3
# 128                  Tours                    3
# 129              Breakfast                    3
# 130               Notaries                    3
# 131              Providers                    3
# 132             Preschools                    3
# 133            Astrologers                    3
# 134          Orthodontists                    3
# 135                Hauling                    3
# 136            Photography                    3
# 137                Therapy                    3
# 138                Doctors                    3

# %% [markdown]
# ### Task 1.3 : Remove categories that appear fewer than 200 times. Write a Python code snippet to perform this operation. Print the number of resulting unique business_categories.

# %%
#Remove categories appearing less than 200x
businesscat_200above = businesscat_count[businesscat_count.business_categories >=200]
businesscat_200above
# Out:
#           index  business_categories
# 0   Restaurants                25212
# 1           Tea                 1116
# 2      Shopping                 1099
# 3       Italian                  960
# 4        Yogurt                  728
# 5        Hotels                  528
# 6          Spas                  498
# 7        Stores                  451
# 8     Nightlife                  399
# 9      Services                  396
# 10      Grocery                  390
# 11         Food                  351
# 12       Venues                  348
# 13  Instruction                  336
# 14   Automotive                  334
# 15       Arenas                  275
# 16      Spirits                  242
# 17        Parks                  235
# 18       Salons                  219
# 19       Cinema                  218
# 20   Bookstores                  208

# %%
#output the length of the resulting cleaned dataset
print("The length of the businesses categories appearing more than 200 times is: ", len(businesscat_200above))
# Out:
# The length of the businesses categories appearing more than 200 times is:  21

# %% [markdown]
# # Task 2: Outliers

# %% [markdown]
# ### Task 2.1: Remove any rows from the sample_data DataFrame (output from Task 1.3) where the `useful` column has a value of 6 or more; Then, create a single figure with two subplots, one showing the boxplot of `useful` column of the original data and the other showing the boxplot of the data with outliers removed.

# %%
#display all rows of business category count data
businesscat_count = sample_data['business_categories'].value_counts()

#display business categories appearing < 200 times
businesscat_less200 = businesscat_count[businesscat_count < 200].index

#display business categories appearing >200times
sample_above200 = sample_data[~sample_data['business_categories'].isin(businesscat_less200)]

#display useful column with <6 values
sample_usefulbelow6 = sample_above200[sample_above200['useful']<6]

#create subplots for Useful (original vs removed outliers)
fig, axs = plt.subplots(ncols=2, figsize = (10,5))
axs[0].set_xlabel('Count of Useful (Original Data)')
axs[1].set_xlabel('Count of Useful (Outliers Removed Data)')

axs[0].boxplot(sample_above200['useful'])
axs[0].set_title('Box Plot of Useful (with outliers)')

axs[1].boxplot(sample_usefulbelow6['useful'])
axs[1].set_title('Box Plot of Useful (w/o outliers)')
# Out:
# Text(0.5, 1.0, 'Box Plot of Useful (w/o outliers)')

# %%
#output the length of the Useful count with outliers removed
print("The length of the Useful Column (with outliers) is: ", len(sample_above200))
print("The length of the Useful Column (outliers removed) is: ", len(sample_usefulbelow6))
# Out:
# The length of the Useful Column (with outliers) is:  34543
# The length of the Useful Column (outliers removed) is:  33564

# %% [markdown]
# ### Task 2.2 : Remove some extremely active users from a dataset (output from Task 2.1) who rate businesses more than 30 times (>30), then create a single figure with two subplots, one showing the boxplot of the count of business rating given by each user and the other showing the boxplot of the data with outliers removed.

# %%
#count of ratings of user_ids
sample_user_ratingcount = sample_usefulbelow6.groupby(['user_id']).size()

#filter users who rate >30 times
users_ratingless30 = sample_user_ratingcount[sample_user_ratingcount <= 30]
clean_usercount = sample_usefulbelow6[sample_usefulbelow6['user_id'].isin(users_ratingless30.index)]

#display count of users with ratings <30
new_usercount = clean_usercount.groupby(['user_id']).size()

# %%
#create subplots fore count of business rating of Users
fig, axs = plt.subplots(ncols=2, figsize = (10,5))
axs[0].set_xlabel('Count (With Outliers)')
axs[1].set_xlabel('Count (Rating Count <30)')

axs[0].boxplot(sample_user_ratingcount)
axs[0].set_title('Box Plot of User Ratings Count (With Outliers)')

axs[1].boxplot(new_usercount)
axs[1].set_title('Box Plot of User Ratings Count (Rating Count < 30)')
# Out:
# Text(0.5, 1.0, 'Box Plot of User Ratings Count (Rating Count < 30)')

# %%
#output the length of the  users with ratings <30
print("The length of the users with ratings (with outliers)  is: ", len(sample_user_ratingcount))
print("The length of the users with ratings <30 is: ", len(new_usercount))
# Out:
# The length of the users with ratings (with outliers)  is:  12864
# The length of the users with ratings <30 is:  12800

# %% [markdown]
# # Task 3: Training a LinearRegression model on the data output from Task 2.2.

# %% [markdown]
# ### Task 3.1: How to build a linear regression model on a subset of the data, using the `useful` column as the input variable and the `stars` column as the output variable. Split the data into a training set and a test set, with 70% of the data used for training. The random_state is set to 42.

# %%
#separate datasets
train, test = train_test_split(clean_usercount, test_size=0.70, random_state=42)
print(train.shape)
print(test.shape)
# Out:
# (9165, 8)
# (21387, 8)

# %%
#input linear regression model values for train and test
reg = linear_model.LinearRegression()
X_train = train[['useful']]
y_train = train['stars']

X_test = test[['useful']]
y_test = test['stars']

reg.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
#prediction and evaluation X Test

predicted = reg.predict(X_test)
mse = ((np.array(y_test)-predicted)**2).sum()/len(y_test)
r2 = r2_score(y_test, predicted)
rmse = np.sqrt(mse)
print("MSE:", mse)
print("RMSE:", rmse)
print("R Squared:", r2)
# Out:
# MSE: 1.516418994279081
# RMSE: 1.2314296546206287
# R Squared: 0.005859907915135465

# %%
#prediction and evaluation X Train

predicted = reg.predict(X_train)
mse = ((np.array(y_train)-predicted)**2).sum()/len(y_train)
r2 = r2_score(y_train, predicted)
rmse = np.sqrt(mse)
print("MSE:", mse)
print("RMSE:", rmse)
print("R Squared:", r2)
# Out:
# MSE: 1.5211067372213265
# RMSE: 1.2333315601334973
# R Squared: 0.0037474586000983967

# %% [markdown]
# ### Task 3.2: Assuming that the number of reviews a business has received  `business_review_count`  can greatly influence the average rating that the business has received. Now, we create the relevant variable to the data, and do the LinearRegression again to the `stars`.

# %%
#count of reviews of business IDs
business_review_count = clean_usercount.groupby(['business_id'])['text'].size().reset_index(name='business_review_count_')

#insert column for business review count
business_review_count.rename(columns={'business_review_count_':'business_review_count'}, inplace=True)

#merge business review count column to the original data
clean_usercount_new = pd.merge(clean_usercount, business_review_count, on='business_id')

# %%
#separate datasets
train, test = train_test_split(clean_usercount_new, test_size=0.70, random_state=42)
print(train.shape)
print(test.shape)
# Out:
# (9165, 9)
# (21387, 9)

# %%
#input linear regression model values for train and test
reg = linear_model.LinearRegression()
X_train = train[['business_review_count']]
y_train = train['stars']


X_test = test[['business_review_count']]
y_test = test['stars']
reg.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
#prediction and evaluation X Test

predicted = reg.predict(X_test)
mse = ((np.array(y_test)-predicted)**2).sum()/len(y_test)
r2 = r2_score(y_test, predicted)
rmse = np.sqrt(mse)
print("MSE:", mse)
print("RMSE:", rmse)
print("R Squared:", r2)
# Out:
# MSE: 1.4919377739186408
# RMSE: 1.2214490467959116
# R Squared: 0.019651641770841444

# %%
#prediction and evaluation X Train

predicted = reg.predict(X_train)
mse = ((np.array(y_train)-predicted)**2).sum()/len(y_train)
r2 = r2_score(y_train, predicted)
rmse = np.sqrt(mse)
print("MSE:", mse)
print("RMSE:", rmse)
print("R Squared:", r2)
# Out:
# MSE: 1.4971575577751484
# RMSE: 1.223583898952233
# R Squared: 0.02433246692037383

# %% [markdown]
# ### Task 3.3: Output the correlations between `business_review_count` and `useful` variables with `stars` and analyze the results.

# %%
clean_usercount_new.corr()
# Out:
#                           stars    useful  business_review_count
# stars                  1.000000 -0.073588               0.146849
# useful                -0.073588  1.000000               0.007573
# business_review_count  0.146849  0.007573               1.000000

# %% [markdown]
# There is a negligible/insignificant correlation between Business Review Count and Useful Variables with Stars. This means that there is no linear relationship between any of two variables. If a business review count increases, it does not mean that stars or useful votes will also increase, or the other way around.
